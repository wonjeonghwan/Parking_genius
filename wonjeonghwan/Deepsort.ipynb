# %% [markdown]
# # SORT

# %% [markdown]
# 1. 영상을 입력 받음<br>
# YOLO 같은 "객체 탐지기"가 이미지에서 물체를 인식해 바운딩 박스를 생성<br>
# 2. 칼만 필터 예측<br>
# 칼만필터 = 시간에 따라 변하는 상태를 추정하는 방법, 모델의 관측값을 바탕으로 현재 상태를 재귀적으로 예측&업데이트하는 알고리즘<br>
# 3. 데이터 연결<br>
# 새로 탐지된 물체와 이전 프레임에서 추적한 물체를 매칭<br>
# 일치, 새로운 물체, 사라진 물체 로 구분<br>
# 4. 트랙 관리<br>
# 일치 - 업데이트 / 새로 나타난 물체 - 새 트랙에 등록 / 사라진 물체 - 일정시간 후 삭제<br>
# 5. 출력<br>
# 각 물체의 위치(바운딩 박스)와 고유한 ID를 출력
# 같은 물체는 같은 ID를 유지하여 "추적"

# %% [markdown]
# # DeepSort

# %% [markdown]
# 1. 영상 입력을 받음<br>
# 위의 1번과 동일<br>
# 2. CNN 특징 추출<br>
# 탐지된 이미지를 Crop하여 CNN을 통해 각 물체의 고유한 특징 벡터(Appearance) 추출<br>
# 벡터 = 얼굴인식정보 의 역할<br>
# 3. 칼만필터 예측 - 이하 동일<br>
# 4. 데이터 연결<br>
# 칼만필터 예측 위치정보, YOLO 위치, CNN 특징 정보 조합하여 매칭<br>
# 5. 트랙 관리<br>
# 일정 시간동안 보이면 "확정 트랙(Confirmed Track)"으로 승격, 사라지면 삭제<br>
# 6. 출력<br>

# %% [markdown]
# 1차 부감 영상의 경우 전혀 자동차를 잡아내지 못함.
# YOLO가 상공에서 본 차량은 잘 인식하지 못한다는 gpt의 분석, 비교적 정면 화면으로 재시도
#
# 2차 도로cctv 영상은 전체적으로 잘 잡음

# %%
import cv2
from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

###########################
# 1. YOLO 11 모델 및 DeepSORT 초기화
yolo_model = YOLO('yolo11n.pt')  # YOLO 11 Nano 모델 (공식 가중치 나오는대로 파일명 확인 필요)
tracker = DeepSort(max_age=30)    # DeepSORT 초기화
###########################

# %%
# 2. 영상 열기
video_path = 'Traffic Camera.mp4'
cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"영상 정보: {width}x{height}, FPS: {fps}")
###########################
# Out:
# 영상 정보: 1920x1080, FPS: 25.0

# %%
###########################
# 3. 결과 저장용 VideoWriter 설정
output_path = 'Parking_tracked02.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # mp4 코덱 설정
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))  # 출력 파일 설정
###########################

# %%
# 4. 프레임별 탐지 및 추적 (차량만 추적)
def detect_and_track(frame):
    results = yolo_model(frame)[0]  # YOLO 11 탐지 실행
    detections = []

    # COCO 기준 차량/이동수단 클래스 ID 리스트
    vehicle_classes = [2, 3, 5, 7]  # 자동차, 오토바이, 버스, 트럭

    for result in results.boxes:
        x1, y1, x2, y2 = map(int, result.xyxy[0])  # 바운딩 박스 좌표
        conf = result.conf[0].item()               # 신뢰도
        class_id = int(result.cls[0].item())       # 클래스 ID

        # 차량만 추적 (클래스 필터링)
        if class_id in vehicle_classes:
            w, h = x2 - x1, y2 - y1
            detections.append([[x1, y1, w, h], conf])  # <- DeepSORT 기대 형식

    # DeepSORT 업데이트 (추적 진행)
    tracks = tracker.update_tracks(detections, frame=frame)

    # 추적 결과 바운딩 박스와 ID 표시
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()  # (left, top, right, bottom)

        # 박스 그리기 & ID 표시
        cv2.rectangle(frame, (int(ltrb[0]), int(ltrb[1])), (int(ltrb[2]), int(ltrb[3])), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {track_id}", (int(ltrb[0]), int(ltrb[1]) - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

    return frame

# %%
###########################

# 5. 메인 루프 - 영상 저장만 하고 화면 출력 안함
frame_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame = detect_and_track(frame)
    out.write(frame)  # 처리된 프레임 저장

    frame_count += 1
    if frame_count % 50 == 0:  # 50프레임마다 진행상황 출력
        print(f"{frame_count} frames processed...")

cap.release()
out.release()
cv2.destroyAllWindows()

print(f"처리 완료. 저장 파일: {output_path}")
###########################
# Out:
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 23.1ms
# Speed: 2.5ms preprocess, 23.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 traffic light, 19.3ms
# Speed: 3.9ms preprocess, 19.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 21.4ms
# Speed: 2.5ms preprocess, 21.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 cars, 1 truck, 1 traffic light, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 17.2ms
# Speed: 2.5ms preprocess, 17.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 2 cars, 1 truck, 1 traffic light, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 15.3ms
# Speed: 2.9ms preprocess, 15.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 15.5ms
# Speed: 3.6ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 16.1ms
# Speed: 2.9ms preprocess, 16.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 15.3ms
# Speed: 2.4ms preprocess, 15.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 19.8ms
# Speed: 2.8ms preprocess, 19.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 17.2ms
# Speed: 2.9ms preprocess, 17.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 18.7ms
# Speed: 3.2ms preprocess, 18.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 13.4ms
# Speed: 4.2ms preprocess, 13.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 15.9ms
# Speed: 3.1ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 17.5ms
# Speed: 3.8ms preprocess, 17.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 13.3ms
# Speed: 2.8ms preprocess, 13.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 11.4ms
# Speed: 3.2ms preprocess, 11.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 18.9ms
# Speed: 4.9ms preprocess, 18.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 10.3ms
# Speed: 1.9ms preprocess, 10.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 20.4ms
# Speed: 4.2ms preprocess, 20.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 12.8ms
# Speed: 2.4ms preprocess, 12.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 traffic light, 22.3ms
# Speed: 2.1ms preprocess, 22.3ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 13.0ms
# Speed: 3.8ms preprocess, 13.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 13.2ms
# Speed: 3.1ms preprocess, 13.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 17.2ms
# Speed: 4.5ms preprocess, 17.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 19.3ms
# Speed: 4.9ms preprocess, 19.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 18.1ms
# Speed: 3.7ms preprocess, 18.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 15.3ms
# Speed: 3.7ms preprocess, 15.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 17.8ms
# Speed: 2.5ms preprocess, 17.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 traffic light, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 16.2ms
# Speed: 3.7ms preprocess, 16.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 11.7ms
# Speed: 2.1ms preprocess, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 50 frames processed...
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 traffic light, 14.8ms
# Speed: 3.5ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 15.8ms
# Speed: 2.4ms preprocess, 15.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 12.3ms
# Speed: 2.4ms preprocess, 12.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 18.0ms
# Speed: 3.3ms preprocess, 18.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 3.6ms preprocess, 13.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 17.0ms
# Speed: 2.7ms preprocess, 17.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 18.5ms
# Speed: 2.7ms preprocess, 18.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 2 traffic lights, 16.7ms
# Speed: 6.2ms preprocess, 16.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 2 traffic lights, 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 2 traffic lights, 15.1ms
# Speed: 4.1ms preprocess, 15.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 2 traffic lights, 13.0ms
# Speed: 3.6ms preprocess, 13.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 2 traffic lights, 18.3ms
# Speed: 2.6ms preprocess, 18.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 13.0ms
# Speed: 5.2ms preprocess, 13.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 16.4ms
# Speed: 4.0ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 2 traffic lights, 13.9ms
# Speed: 2.9ms preprocess, 13.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 2 traffic lights, 17.5ms
# Speed: 4.7ms preprocess, 17.5ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 2 traffic lights, 16.5ms
# Speed: 3.2ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 18.0ms
# Speed: 3.7ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 3 traffic lights, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 2 traffic lights, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 3 traffic lights, 12.0ms
# Speed: 2.4ms preprocess, 12.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 3 traffic lights, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 3 traffic lights, 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 19.1ms
# Speed: 2.3ms preprocess, 19.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 18.6ms
# Speed: 3.3ms preprocess, 18.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 13.5ms
# Speed: 4.6ms preprocess, 13.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 18.6ms
# Speed: 3.2ms preprocess, 18.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 14.8ms
# Speed: 2.7ms preprocess, 14.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 19.1ms
# Speed: 2.6ms preprocess, 19.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 19.0ms
# Speed: 3.1ms preprocess, 19.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.8ms
# Speed: 2.9ms preprocess, 13.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 13.8ms
# Speed: 4.5ms preprocess, 13.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 traffic lights, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 traffic lights, 19.1ms
# Speed: 2.8ms preprocess, 19.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.5ms
# Speed: 2.8ms preprocess, 21.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.9ms
# Speed: 2.6ms preprocess, 19.9ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.0ms
# Speed: 3.1ms preprocess, 17.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 100 frames processed...
#
# 0: 384x640 4 cars, 13.9ms
# Speed: 2.7ms preprocess, 13.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.3ms
# Speed: 3.0ms preprocess, 18.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 19.9ms
# Speed: 3.4ms preprocess, 19.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 12.5ms
# Speed: 2.7ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 traffic light, 21.3ms
# Speed: 5.9ms preprocess, 21.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 14.9ms
# Speed: 4.2ms preprocess, 14.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 19.9ms
# Speed: 2.7ms preprocess, 19.9ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 18.8ms
# Speed: 3.0ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 3.1ms preprocess, 14.6ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 19.9ms
# Speed: 3.2ms preprocess, 19.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.7ms
# Speed: 3.2ms preprocess, 20.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 17.7ms
# Speed: 4.7ms preprocess, 17.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 3.3ms preprocess, 15.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 2 traffic lights, 19.1ms
# Speed: 5.7ms preprocess, 19.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.3ms
# Speed: 3.6ms preprocess, 21.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 22.3ms
# Speed: 2.3ms preprocess, 22.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.7ms
# Speed: 2.2ms preprocess, 11.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 19.4ms
# Speed: 3.3ms preprocess, 19.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.6ms
# Speed: 4.6ms preprocess, 20.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.8ms
# Speed: 4.1ms preprocess, 18.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 23.4ms
# Speed: 3.8ms preprocess, 23.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 13.1ms
# Speed: 3.8ms preprocess, 13.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 10.6ms
# Speed: 2.5ms preprocess, 10.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 10.2ms
# Speed: 3.1ms preprocess, 10.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.6ms
# Speed: 3.2ms preprocess, 17.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 19.4ms
# Speed: 2.9ms preprocess, 19.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 18.1ms
# Speed: 3.8ms preprocess, 18.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 18.2ms
# Speed: 3.8ms preprocess, 18.2ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.6ms
# Speed: 2.8ms preprocess, 13.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.4ms
# Speed: 2.5ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.3ms
# Speed: 3.7ms preprocess, 13.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.1ms
# Speed: 3.2ms preprocess, 33.1ms inference, 14.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 11.6ms
# Speed: 2.7ms preprocess, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.0ms
# Speed: 2.7ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 11.0ms
# Speed: 2.3ms preprocess, 11.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 13.2ms
# Speed: 2.4ms preprocess, 13.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 150 frames processed...
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 13.5ms
# Speed: 3.0ms preprocess, 13.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 9.7ms
# Speed: 3.4ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 3 traffic lights, 17.0ms
# Speed: 2.9ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 2 traffic lights, 20.3ms
# Speed: 3.0ms preprocess, 20.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 11.6ms
# Speed: 2.2ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 1 traffic light, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 truck, 1 traffic light, 10.1ms
# Speed: 2.2ms preprocess, 10.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 1 traffic light, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 12.2ms
# Speed: 2.4ms preprocess, 12.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 2 trucks, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 1 traffic light, 12.2ms
# Speed: 3.6ms preprocess, 12.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.7ms
# Speed: 2.4ms preprocess, 13.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 21.3ms
# Speed: 2.9ms preprocess, 21.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 19.9ms
# Speed: 3.5ms preprocess, 19.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 12.6ms
# Speed: 2.5ms preprocess, 12.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 traffic light, 17.2ms
# Speed: 2.4ms preprocess, 17.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 11.1ms
# Speed: 2.4ms preprocess, 11.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 12.1ms
# Speed: 2.9ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 15.0ms
# Speed: 2.8ms preprocess, 15.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 16.9ms
# Speed: 3.3ms preprocess, 16.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.2ms
# Speed: 3.4ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 18.2ms
# Speed: 2.7ms preprocess, 18.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 19.1ms
# Speed: 3.1ms preprocess, 19.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.2ms
# Speed: 3.9ms preprocess, 12.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.0ms
# Speed: 4.5ms preprocess, 17.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 22.4ms
# Speed: 2.6ms preprocess, 22.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 19.6ms
# Speed: 3.1ms preprocess, 19.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 3.0ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.0ms
# Speed: 3.7ms preprocess, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.0ms
# Speed: 2.2ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 14.1ms
# Speed: 3.3ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 21.7ms
# Speed: 2.5ms preprocess, 21.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# 200 frames processed...
#
# 0: 384x640 3 cars, 1 truck, 20.2ms
# Speed: 4.1ms preprocess, 20.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 14.8ms
# Speed: 3.4ms preprocess, 14.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 11.9ms
# Speed: 4.4ms preprocess, 11.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.3ms
# Speed: 3.2ms preprocess, 17.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 15.8ms
# Speed: 2.8ms preprocess, 15.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 20.3ms
# Speed: 4.4ms preprocess, 20.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 16.6ms
# Speed: 2.9ms preprocess, 16.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 3.9ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.8ms preprocess, 14.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 19.3ms
# Speed: 2.5ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 21.0ms
# Speed: 2.5ms preprocess, 21.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.7ms
# Speed: 2.6ms preprocess, 17.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 18.6ms
# Speed: 3.8ms preprocess, 18.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 22.1ms
# Speed: 3.4ms preprocess, 22.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 15.5ms
# Speed: 3.0ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 17.1ms
# Speed: 3.7ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.8ms
# Speed: 4.9ms preprocess, 21.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 18.8ms
# Speed: 3.7ms preprocess, 18.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 15.1ms
# Speed: 3.6ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 15.6ms
# Speed: 4.7ms preprocess, 15.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 18.5ms
# Speed: 3.3ms preprocess, 18.5ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.9ms
# Speed: 2.7ms preprocess, 16.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.2ms
# Speed: 2.5ms preprocess, 12.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.2ms
# Speed: 2.3ms preprocess, 19.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8.8ms
# Speed: 3.4ms preprocess, 8.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 3.5ms preprocess, 17.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 23.7ms
# Speed: 6.3ms preprocess, 23.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.7ms
# Speed: 3.0ms preprocess, 19.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.4ms
# Speed: 2.1ms preprocess, 12.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.6ms
# Speed: 3.2ms preprocess, 21.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 4.6ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.3ms
# Speed: 3.6ms preprocess, 17.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# 250 frames processed...
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 5.3ms preprocess, 18.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.2ms
# Speed: 5.8ms preprocess, 11.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.4ms
# Speed: 2.7ms preprocess, 19.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.1ms
# Speed: 2.5ms preprocess, 16.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 3.5ms preprocess, 11.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.6ms
# Speed: 2.8ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.7ms
# Speed: 2.6ms preprocess, 17.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.2ms
# Speed: 5.6ms preprocess, 21.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.8ms
# Speed: 2.8ms preprocess, 12.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 4.3ms preprocess, 18.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.7ms
# Speed: 4.2ms preprocess, 19.7ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 14.1ms
# Speed: 3.0ms preprocess, 14.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 9.9ms
# Speed: 5.4ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 10.0ms
# Speed: 6.7ms preprocess, 10.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.6ms
# Speed: 2.3ms preprocess, 13.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 12.1ms
# Speed: 2.5ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.7ms
# Speed: 4.8ms preprocess, 17.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.9ms
# Speed: 5.4ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 12.3ms
# Speed: 2.9ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.7ms
# Speed: 2.9ms preprocess, 11.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 20.0ms
# Speed: 3.4ms preprocess, 20.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 16.4ms
# Speed: 2.6ms preprocess, 16.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 13.4ms
# Speed: 4.6ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 11.2ms
# Speed: 2.8ms preprocess, 11.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 18.1ms
# Speed: 5.9ms preprocess, 18.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.8ms
# Speed: 2.2ms preprocess, 12.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 46.1ms
# Speed: 2.8ms preprocess, 46.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
# 300 frames processed...
#
# 0: 384x640 3 cars, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 19.0ms
# Speed: 3.7ms preprocess, 19.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.5ms
# Speed: 3.4ms preprocess, 19.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.2ms
# Speed: 4.8ms preprocess, 19.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.9ms
# Speed: 3.3ms preprocess, 20.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 3.5ms preprocess, 15.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.8ms
# Speed: 2.7ms preprocess, 19.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.3ms
# Speed: 4.5ms preprocess, 18.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 2.1ms preprocess, 11.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 28.1ms
# Speed: 20.3ms preprocess, 28.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 traffic light, 14.9ms
# Speed: 2.9ms preprocess, 14.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 11.2ms
# Speed: 3.5ms preprocess, 11.2ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.4ms
# Speed: 2.6ms preprocess, 13.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 17.2ms
# Speed: 5.9ms preprocess, 17.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 18.4ms
# Speed: 2.9ms preprocess, 18.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 18.1ms
# Speed: 2.4ms preprocess, 18.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.2ms
# Speed: 2.9ms preprocess, 19.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 25.4ms
# Speed: 2.6ms preprocess, 25.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 19.2ms
# Speed: 3.1ms preprocess, 19.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 20.3ms
# Speed: 2.7ms preprocess, 20.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 17.6ms
# Speed: 3.1ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 17.5ms
# Speed: 2.8ms preprocess, 17.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 18.4ms
# Speed: 2.5ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 3 cars, 13.2ms
# Speed: 3.2ms preprocess, 13.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 14.4ms
# Speed: 2.6ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 17.0ms
# ...
# Speed: 5.4ms preprocess, 19.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 9.1ms
# Speed: 4.2ms preprocess, 9.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.0ms
# Speed: 1.8ms preprocess, 15.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 13.6ms
# Speed: 3.2ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 12.4ms
# Speed: 5.9ms preprocess, 12.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 11.2ms
# Speed: 5.0ms preprocess, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 5.0ms preprocess, 14.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 11.3ms
# Speed: 2.6ms preprocess, 11.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 10.1ms
# Speed: 3.2ms preprocess, 10.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.0ms
# Speed: 4.3ms preprocess, 15.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 12.9ms
# Speed: 4.4ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.8ms
# Speed: 2.7ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.7ms
# Speed: 7.0ms preprocess, 18.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 24.4ms
# Speed: 2.3ms preprocess, 24.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 12.0ms
# Speed: 4.2ms preprocess, 12.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 11.8ms
# Speed: 2.6ms preprocess, 11.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.5ms
# Speed: 2.8ms preprocess, 12.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 2.9ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.5ms
# Speed: 5.1ms preprocess, 17.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# 650 frames processed...
#
# 0: 384x640 4 cars, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 2.8ms preprocess, 16.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 13.0ms
# Speed: 2.7ms preprocess, 13.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.8ms
# Speed: 2.7ms preprocess, 12.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.1ms
# Speed: 3.5ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 17.6ms
# Speed: 2.8ms preprocess, 17.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 10.6ms
# Speed: 2.3ms preprocess, 10.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 19.4ms
# Speed: 2.5ms preprocess, 19.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 19.5ms
# Speed: 2.5ms preprocess, 19.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.3ms
# Speed: 4.1ms preprocess, 21.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.9ms
# Speed: 3.0ms preprocess, 12.9ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 3.4ms preprocess, 17.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 3.6ms preprocess, 14.2ms inference, 20.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 12.3ms
# Speed: 3.9ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.8ms
# Speed: 4.1ms preprocess, 18.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.1ms
# Speed: 2.7ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.6ms
# Speed: 2.3ms preprocess, 19.6ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 2.7ms preprocess, 17.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.3ms
# Speed: 2.6ms preprocess, 13.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 22.3ms
# Speed: 5.0ms preprocess, 22.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 10.6ms
# Speed: 4.7ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.7ms
# Speed: 3.3ms preprocess, 17.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.5ms
# Speed: 3.4ms preprocess, 17.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.6ms
# Speed: 4.1ms preprocess, 11.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.5ms
# Speed: 2.7ms preprocess, 13.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 3.1ms preprocess, 18.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.0ms
# Speed: 3.4ms preprocess, 11.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.0ms
# Speed: 2.6ms preprocess, 12.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.4ms preprocess, 15.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.6ms
# Speed: 2.8ms preprocess, 20.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 700 frames processed...
#
# 0: 384x640 3 cars, 13.8ms
# Speed: 5.7ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 19.0ms
# Speed: 5.5ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.6ms
# Speed: 2.7ms preprocess, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.6ms
# Speed: 4.1ms preprocess, 13.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.0ms
# Speed: 2.6ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 57.4ms
# Speed: 3.6ms preprocess, 57.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.7ms
# Speed: 3.2ms preprocess, 44.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.6ms
# Speed: 2.9ms preprocess, 17.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 3.4ms preprocess, 14.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.7ms
# Speed: 3.1ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 16.3ms
# Speed: 2.6ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.9ms preprocess, 14.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 3 cars, 18.8ms
# Speed: 3.4ms preprocess, 18.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 21.1ms
# Speed: 2.5ms preprocess, 21.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.5ms
# Speed: 2.7ms preprocess, 17.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 15.4ms
# Speed: 3.4ms preprocess, 15.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 11.6ms
# Speed: 3.6ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.0ms
# Speed: 3.1ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 23.6ms
# Speed: 3.5ms preprocess, 23.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.2ms
# Speed: 2.1ms preprocess, 22.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.3ms
# Speed: 3.0ms preprocess, 17.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 10.4ms
# Speed: 3.8ms preprocess, 10.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 12.1ms
# Speed: 2.7ms preprocess, 12.1ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.2ms
# Speed: 3.6ms preprocess, 20.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.3ms
# Speed: 2.7ms preprocess, 20.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.4ms
# Speed: 3.5ms preprocess, 18.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.3ms
# Speed: 2.7ms preprocess, 22.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.2ms
# Speed: 3.4ms preprocess, 10.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.4ms
# Speed: 2.3ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.3ms
# Speed: 4.9ms preprocess, 20.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.8ms
# Speed: 4.0ms preprocess, 17.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# 750 frames processed...
# 처리 완료. 저장 파일: Parking_tracked02.mp4
